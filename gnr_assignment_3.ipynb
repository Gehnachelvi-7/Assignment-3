# %%
import torch
print("GPU Available:", torch.cuda.is_available())
# Out:
# GPU Available: True

# %%
# !rm -rf Assignment-3
# !git clone https://github.com/Gehnachelvi-7/Assignment-3.git
# %cd Assignment-3
# Out:
# Cloning into 'Assignment-3'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 19 (delta 7), reused 18 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 4.69 KiB | 4.69 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/Assignment-3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm -rf /content/drive/MyDrive/resnet_results

# %%
import os

save_path = "/content/drive/MyDrive/resnet_results"
os.makedirs(save_path, exist_ok=True)

print("Save path:", save_path)
# Out:
# Save path: /content/drive/MyDrive/resnet_results

# %%
import time

start_time = time.time()

# !python train_custom.py

end_time = time.time()
total_time = end_time - start_time

print("Training Time (seconds):", total_time)

with open("extra_time.txt", "w") as f:
    f.write(str(total_time))
# Out:
# 100% 170M/170M [00:03<00:00, 48.8MB/s]
# Epoch 1: Loss=980.12, Accuracy=62.56%, Time=40.30s
# Epoch 2: Loss=622.22, Accuracy=73.67%, Time=40.70s
# Epoch 3: Loss=474.10, Accuracy=72.64%, Time=41.69s
# Epoch 4: Loss=379.23, Accuracy=76.64%, Time=42.42s
# Epoch 5: Loss=310.36, Accuracy=79.97%, Time=41.92s
#
# Final Custom Accuracy: 79.97
# Total Training Time: 207.02658343315125
# Parameters: 2779914
# Training Time (seconds): 217.80878567695618

# %%
# !python official_eval.py

# !cp *.txt /content/drive/MyDrive/resnet_results/
# !cp *.pth /content/drive/MyDrive/resnet_results/
# Out:
# Epoch 1: Loss=780.27, Accuracy=76.32%, Time=29.66s
# Epoch 2: Loss=450.77, Accuracy=79.29%, Time=29.92s
# Epoch 3: Loss=326.00, Accuracy=80.66%, Time=29.55s
# Epoch 4: Loss=232.22, Accuracy=81.17%, Time=30.26s
# Epoch 5: Loss=166.10, Accuracy=81.09%, Time=29.50s
#
# Final Official Accuracy: 81.09
# Parameters: 11181642
#
# Comparison saved in final_results.txt

# %%
# !ls /content/drive/MyDrive/resnet_results
# Out:
# custom_model.pth  custom_results.txt  extra_time.txt  final_results.txt
